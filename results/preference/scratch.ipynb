# %%
import pandas as pd


data = pd.read_json("results_combined.jsonl", lines=True)
data
# Out:
#       id  fable_id                                             fable1  \
# 0    757         1  A badger, crossing a bridge over a river with ...
# 1    946         1  A hungry fox was stalking a rabbit one sunny a...
# 2    757         1  A badger, crossing a bridge over a river with ...
# 3    946         1  A hungry fox was stalking a rabbit one sunny a...
# 4    757         1  A badger, crossing a bridge over a river with ...
# 5    946         1  A hungry fox was stalking a rabbit one sunny a...
# 6   1891         1  Once upon a time, in a lush forest, a curious ...
# 7   2080         1  A hungry fox was stalking a rabbit one sunny a...
# 8   1891         1  Once upon a time, in a lush forest, a curious ...
# 9   2080         1  A hungry fox was stalking a rabbit one sunny a...
# 10  1891         1  Once upon a time, in a lush forest, a curious ...
# 11  2080         1  A hungry fox was stalking a rabbit one sunny a...
# ...

# %%
data[["preference_raw", "preference"]]
# Out:
#                     preference_raw preference
# 0          {"my_choice": "Fable2"}     fable2
# 1          {"my_choice": "Fable2"}     fable2
# 2          {"my_choice": "Fable2"}     fable2
# 3          {"my_choice": "Fable2"}     fable2
# 4          {"my_choice": "Fable2"}     fable2
# 5          {"my_choice": "Fable1"}     fable1
# 6          {"my_choice": "Fable2"}     fable2
# 7          {"my_choice": "Fable2"}     fable2
# 8          {"my_choice": "Fable1"}     fable1
# 9          {"my_choice": "Fable1"}     fable1
# 10         {"my_choice": "Fable2"}     fable2
# 11         {"my_choice": "Fable1"}     fable1
# 12   {\n  "my_choice": "Fable2"\n}     fable2
# 13   {\n  "my_choice": "Fable1"\n}     fable1
# 14         {"my_choice": "Fable2"}     fable2
# 15         {"my_choice": "Fable1"}     fable1
# 16         {"my_choice": "Fable2"}     fable2
# 17         {"my_choice": "Fable1"}     fable1
# 18         {"my_choice": "Fable2"}     fable2
# ...

# %%
import seaborn as sns
sns.countplot(
    data=data,
    x="predictor",
    hue="preferred_generator",
)
# Out:
# <Axes: xlabel='predictor', ylabel='count'>
